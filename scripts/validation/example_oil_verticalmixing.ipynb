# %% [markdown]
# # Oil vertical mixing

# %%
import os
from datetime import timedelta
from opendrift.readers import reader_netCDF_CF_generic
from opendrift.models.openoil import OpenOil


o = OpenOil(loglevel=0)  # Set loglevel to 0 for debug information

ncfile = 'driftmapcomparison.nc'
import_file = True  # Set to True to import previous run

if import_file is True:
    o.io_import_file(ncfile)
else:
    reader_arome = reader_netCDF_CF_generic.Reader('https://thredds.met.no/thredds/dodsC/mepslatest/meps_lagged_6_h_latest_2_5km_latest.nc')
    reader_norkyst = reader_netCDF_CF_generic.Reader('https://thredds.met.no/thredds/dodsC/fou-hi/norkystv3_800m_m00_be')

    o.add_reader([reader_norkyst, reader_arome])

    # Adjusting some configuration
    o.set_config('drift:vertical_mixing', False)
    o.set_config('drift:advection_scheme', 'runge-kutta4')
    # Seed oil elements at defined position and time
    o.seed_elements(lon=4.9, lat=62.1, z=0, radius=1000, number=10000,
                    time=reader_arome.start_time, oil_type='GENERIC DIESEL')

    # Running model
    o.run(end_time=reader_arome.start_time + timedelta(hours=12),
          time_step=900, time_step_output=1800, outfile=ncfile)
# Out:
# 00:49:47 DEBUG   opendrift.config:168: Adding 17 config items from __init__
# 00:49:47 DEBUG   opendrift.config:178:   Overwriting config item readers:max_number_of_fails
# 00:49:47 DEBUG   opendrift.config:168: Adding 6 config items from __init__
# 00:49:47 INFO    opendrift:569: OpenDriftSimulation initialised (version 1.14.10)
# 00:49:47 DEBUG   opendrift.config:168: Adding 19 config items from oceandrift
# 00:49:47 DEBUG   opendrift.config:178:   Overwriting config item seed:z
# 00:49:47 DEBUG   opendrift.config:168: Adding 15 config items from openoil
# 00:49:47 DEBUG   opendrift.export.io_netcdf:113: Importing from driftmapcomparison.nc
# WARNING: from next version (1.14.10), loglevel of 0 will give no logging, please change to 10 for DEBUG
# 00:49:47 DEBUG   opendrift:1807: No elements to deactivate
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:x_sea_water_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:x_sea_water_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:y_sea_water_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:y_sea_water_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:x_wind -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:x_wind -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:y_wind -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:y_wind -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_surface_height -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_surface_height -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:upward_sea_water_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:upward_sea_water_velocity -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_surface_wave_significant_height -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_surface_wave_significant_height -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_x_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_x_velocity -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_surface_wave_stokes_drift_y_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_surface_wave_stokes_drift_y_velocity -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_surface_wave_period_at_variance_spectral_density_maximum -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_surface_wave_period_at_variance_spectral_density_maximum -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_ice_area_fraction -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_ice_area_fraction -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_ice_x_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_ice_x_velocity -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_ice_y_velocity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_ice_y_velocity -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_water_temperature -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_water_temperature -> 10
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_water_salinity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_water_salinity -> 34
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:sea_floor_depth_below_sea_level -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:sea_floor_depth_below_sea_level -> 10000
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:horizontal_diffusivity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:horizontal_diffusivity -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:ocean_vertical_diffusivity -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:ocean_vertical_diffusivity -> 0.02
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:land_binary_mask -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:land_binary_mask -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:constant:ocean_mixed_layer_thickness -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: environment:fallback:ocean_mixed_layer_thickness -> 50
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: general:use_auto_landmask -> True
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:current_uncertainty -> 0.05
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:current_uncertainty_uniform -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:max_speed -> 1.3
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: readers:max_number_of_fails -> 1
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: general:simulation_name ->
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: general:coastline_action -> stranding
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: general:coastline_approximation_precision -> 0.001
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: general:time_step_minutes -> 60
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: general:time_step_output_minutes -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:ocean_only -> True
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:number -> 1
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:max_age_seconds -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:advection_scheme -> runge-kutta4
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:profiles_depth -> 50
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:wind_uncertainty -> 0.5
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:relative_wind -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:deactivate_north_of -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:deactivate_south_of -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:deactivate_east_of -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:deactivate_west_of -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:origin_marker -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:z -> 0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:wind_drift_factor -> 0.03
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:current_drift_factor -> 1
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:terminal_velocity -> 0.0
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:oil_film_thickness -> 0.001
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:vertical_advection -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:vertical_advection_at_surface -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:water_column_stretching -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:vertical_advection_correction -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:vertical_mixing -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:vertical_mixing_at_surface -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: vertical_mixing:timestep -> 60
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: vertical_mixing:diffusivitymodel -> environment
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: vertical_mixing:background_diffusivity -> 1.2e-05
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: vertical_mixing:TSprofiles -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:wind_drift_depth -> 0.1
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:stokes_drift -> True
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:stokes_drift_profile -> Phillips
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:use_tabularised_stokes_drift -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:tabularised_stokes_drift_fetch -> 25000
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: general:seafloor_action -> lift_to_seafloor
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: drift:truncate_ocean_model_below_m -> None
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:seafloor -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:m3_per_hour -> 1
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:droplet_size_distribution -> uniform
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:droplet_diameter_mu -> 0.001
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:droplet_diameter_sigma -> 0.0005
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:droplet_diameter_min_subsea -> 0.0005
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:droplet_diameter_max_subsea -> 0.005
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: processes:dispersion -> True
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: processes:evaporation -> True
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: processes:emulsification -> True
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: processes:biodegradation -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: biodegradation:method -> Adcroft
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: processes:update_oilfilm_thickness -> False
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: wave_entrainment:droplet_size_distribution -> Johansen et al. (2015)
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: wave_entrainment:entrainment_rate -> Li et al. (2017)
# 00:49:47 DEBUG   opendrift.export.io_netcdf:157: Setting imported config: seed:oil_type -> GENERIC DIESEL

# %% [markdown]
# Print and plot results

# %%
print(o)

o.plot(linecolor='z', fast=True)
o.plot_property('z')
o.plot_oil_budget()
o.animation(fast=True)

os.remove(ncfile)  # cleaning up
# Out:
# 00:52:07 DEBUG   opendrift:2555: Setting up map: corners=None, fast=True, lscale=None
# 00:52:07 WARNING opendrift:2589: Plotting fast. This will make your plots less accurate.
# ===========================
# --------------------
# Reader performance:
# --------------------
# Performance:
#       0 total time
#       0 configuration
# --------------------
# ===========================
# Model:	OpenOil     (OpenDrift version 1.14.10)
# 	10000 active Oil particles  (0 deactivated, 0 scheduled)
# -------------------
# Environment variables:
#   -----
# Readers not added for the following variables:
#   horizontal_diffusivity
#   land_binary_mask
#   ocean_mixed_layer_thickness
#   ocean_vertical_diffusivity
#   sea_floor_depth_below_sea_level
#   sea_ice_area_fraction
#   sea_ice_x_velocity
#   sea_ice_y_velocity
#   sea_surface_height
#   sea_surface_wave_mean_period_from_variance_spectral_density_second_frequency_moment
#   sea_surface_wave_period_at_variance_spectral_density_maximum
#   sea_surface_wave_significant_height
#   sea_surface_wave_stokes_drift_x_velocity
#   sea_surface_wave_stokes_drift_y_velocity
#   sea_water_salinity
#   sea_water_temperature
#   upward_sea_water_velocity
#   x_sea_water_velocity
#   x_wind
#   y_sea_water_velocity
#   y_wind
#
# Discarded readers:
#
# Time:
# 	Start: 2026-09-11 15:00:00 UTC
# 	Present: 2026-09-12 03:00:00 UTC
# 	Calculation steps: 0 * 0:15:00 - total time: 12:00:00
# 	Output steps: 25 * 0:30:00
# ===========================
# 00:52:08 DEBUG   opendrift:3236: Showing animation..
# 00:52:08 INFO    opendrift:3246: Preparing animation for notebook....
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img54319cc4995a41ac9871202f03f71288">
#   <div class="anim-controls">
#     <input id="_anim_slider54319cc4995a41ac9871202f03f71288" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim54319cc4995a41ac9871202f03f71288.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim54319cc4995a41ac9871202f03f71288.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim54319cc4995a41ac9871202f03f71288.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim54319cc4995a41ac9871202f03f71288.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim54319cc4995a41ac9871202f03f71288.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim54319cc4995a41ac9871202f03f71288.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim54319cc4995a41ac9871202f03f71288.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim54319cc4995a41ac9871202f03f71288.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim54319cc4995a41ac9871202f03f71288.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim54319cc4995a41ac9871202f03f71288.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select54319cc4995a41ac9871202f03f71288"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_54319cc4995a41ac9871202f03f71288"
#              >
#       <label for="_anim_radio1_54319cc4995a41ac9871202f03f71288">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_54319cc4995a41ac9871202f03f71288"
#              checked>
#       <label for="_anim_radio2_54319cc4995a41ac9871202f03f71288">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_54319cc4995a41ac9871202f03f71288"
#              >
#       <label for="_anim_radio3_54319cc4995a41ac9871202f03f71288">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img54319cc4995a41ac9871202f03f71288";
#     var slider_id = "_anim_slider54319cc4995a41ac9871202f03f71288";
#     var loop_select_id = "_anim_loop_select54319cc4995a41ac9871202f03f71288";
#     var frames = new Array(25);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjExLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvctoD+AAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAhAxJR
# 00:52:12 INFO    opendrift:3217: Time to make animation: 0:00:05.314146

# %% [markdown]
# <img src="file://gallery/animations/example_oil_verticalmixing_0.gif">
# <img src="file://gallery/animations/example_oil_verticalmixing_1.gif">
